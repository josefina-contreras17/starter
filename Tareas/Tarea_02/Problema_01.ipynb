# %%
# lista desde -30 al 50
lista_numeros = range(-30, 50)
print (lista_numeros)

for x in range(-30, 51):
  if (x < 0):
    print (x,"muy frío")
  elif (x >= 0 and x <= 24):
   print (x,"templado")
  else
    print (x,"caluroso")
# Out:
# range(-30, 50)
# -30 muy frío
# -29 muy frío
# -28 muy frío
# -27 muy frío
# -26 muy frío
# -25 muy frío
# -24 muy frío
# -23 muy frío
# -22 muy frío
# -21 muy frío
# -20 muy frío
# -19 muy frío
# -18 muy frío
# -17 muy frío
# -16 muy frío
# -15 muy frío
# -14 muy frío
# -13 muy frío
# -12 muy frío
# -11 muy frío
# -10 muy frío
# -9 muy frío
# -8 muy frío
# -7 muy frío
# -6 muy frío
# -5 muy frío
# -4 muy frío
# -3 muy frío
# -2 muy frío
# -1 muy frío
# 0 templado
# 1 templado
# 2 templado
# 3 templado
# 4 templado
# 5 templado
# 6 templado
# 7 templado
# 8 templado
# 9 templado
# 10 templado
# 11 templado
# 12 templado
# 13 templado
# 14 templado
# 15 templado
# 16 templado
# 17 templado
# 18 templado
# 19 templado
# 20 templado
# 21 templado
# 22 templado
# 23 templado
# 24 templado
# 25 caluroso
# 26 caluroso
# 27 caluroso
# 28 caluroso
# 29 caluroso
# 30 caluroso
# 31 caluroso
# 32 caluroso
# 33 caluroso
# 34 caluroso
# 35 caluroso
# 36 caluroso
# 37 caluroso
# 38 caluroso
# ...

# %% [markdown]
# crea un programa que imprima los n del -30 al 50
# Cada número, además de imprimirlo, el programa debe mostrat un texto según estas reglas:
# si el número es menor que 0, mostrar "muy frío". si el número está entre 0 y 24 "templado", si el número es mayor o igual a 25, "caluroso"
